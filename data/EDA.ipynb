# %%
import json
with open("sotopia_pi_openai_log_attribution.jsonl") as f:
    data = [json.loads(line) for line in f]

# %%
episode_scores = []
for log in data:
    scores = []
    agent = log['agent']
    for key in log['attributed_utterances']:
        if agent in key:
            scores.append(log['attributed_utterances'][key][1])
    episode_scores.append(scores)

# %%
print(len(episode_scores))
# Out:
# 4562

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.51.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 2.4 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in /root/.cache/pypoetry/virtualenvs/sotopia-rl-4gc-Ucyx-py3.10/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /root/.cache/pypoetry/virtualenvs/sotopia-rl-4gc-Ucyx-py3.10/lib/python3.10/site-packages (from matplotlib) (24.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /root/.cache/pypoetry/virtualenvs/sotopia-rl-4gc-Ucyx-py3.10/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /root/.cache/pypoetry/virtualenvs/sotopia-rl-4gc-Ucyx-py3.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 45.5 MB/s eta 0:00:0000:0100:01
# Downloading contourpy-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (305 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.2/305.2 kB 107.1 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.51.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 90.4 MB/s eta 0:00:00ta 0:00:01
# Downloading kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 94.1 MB/s eta 0:00:00
# Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 77.0 MB/s eta 0:00:00ta 0:00:01
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 33.9 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.51.0 kiwisolver-1.4.5 matplotlib-3.9.0 pillow-10.3.0 pyparsing-3.1.2

# %%
# plot the distribution of average score of each episode
import matplotlib.pyplot as plt
import numpy as np
average_scores = [sum(scores) / len(scores) for scores in episode_scores if len(scores) > 0]
plt.hist(average_scores, bins=20)
plt.xlabel('Average score of each episode')
plt.ylabel('Frequency')
plt.title('Distribution of average score of each episode')
# Out:
# Text(0.5, 1.0, 'Distribution of average score of each episode')

# %%
# plot the length of each episode
len_episodes = [len(scores) for scores in episode_scores]
plt.figure()
plt.hist(len_episodes, bins=20)
plt.xlabel('Length of each episode')
plt.ylabel('Frequency')
plt.title('Distribution of length of each episode')
# Out:
# Text(0.5, 1.0, 'Distribution of length of each episode')

# %%
# plot the distribution of max score of each episode

max_scores = [max(scores) for scores in episode_scores if len(scores) > 0]
plt.hist(max_scores, bins=20)
plt.xlabel('Max score of each episode')
plt.ylabel('Frequency')
plt.title('Distribution of max score of each episode')
# Out:
# Text(0.5, 1.0, 'Distribution of max score of each episode')

# %%
# plot the distribution of min score of each episode

max_scores = [min(scores) for scores in episode_scores if len(scores) > 0]
plt.hist(max_scores, bins=20)
plt.xlabel('Min score of each episode')
plt.ylabel('Frequency')
plt.title('Distribution of min score of each episode')
# Out:
# Text(0.5, 1.0, 'Distribution of min score of each episode')
